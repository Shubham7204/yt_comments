# %% [markdown]
# <a href="https://colab.research.google.com/github/analyticswithadam/Python/blob/main/YouTubeComments.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Pull Comments

# %%
import googleapiclient.discovery
import googleapiclient.errors

api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = ""

youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=DEVELOPER_KEY)

request = youtube.commentThreads().list(
    part="snippet",
    videoId="WNrB1Q9Rry0",
    maxResults=100
)
response = request.execute()

for item in response['items']:
    print(item['snippet']['topLevelComment']['snippet']['textDisplay'])
# Out:
# ---------------------------------------------------------------------------
# DefaultCredentialsError                   Traceback (most recent call last)
# Cell In[1], line 8
#       5 api_version = "v3"
#       6 DEVELOPER_KEY = ""
# ----> 8 youtube = googleapiclient.discovery.build(
#       9     api_service_name, api_version, developerKey=DEVELOPER_KEY)
#      11 request = youtube.commentThreads().list(
#      12     part="snippet",
#      13     videoId="WNrB1Q9Rry0",
#      14     maxResults=100
#      15 )
#      16 response = request.execute()
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\googleapiclient\_helpers.py:134, in positional.<locals>.positional_decorator.<locals>.positional_wrapper(*args, **kwargs)
#     132     elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     133         logger.warning(message)
# --> 134 return wrapped(*args, **kwargs)
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\googleapiclient\discovery.py:276, in build(serviceName, version, http, discoveryServiceUrl, developerKey, model, requestBuilder, credentials, cache_discovery, cache, client_options, adc_cert_path, adc_key_path, num_retries)
#     267 try:
#     268     content = _retrieve_discovery_doc(
#     269         requested_url,
#     270         discovery_http,
#    (...)
#     274         num_retries=num_retries,
#     275     )
# --> 276     return build_from_document(
#     277         content,
#     278         base=discovery_url,
#     279         http=http,
#     280         developerKey=developerKey,
#     281         model=model,
#     282         requestBuilder=requestBuilder,
#     283         credentials=credentials,
#     284         client_options=client_options,
#     285         adc_cert_path=adc_cert_path,
#     286         adc_key_path=adc_key_path,
#     287     )
#     288 except HttpError as e:
#     289     if e.resp.status == http_client.NOT_FOUND:
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\googleapiclient\_helpers.py:134, in positional.<locals>.positional_decorator.<locals>.positional_wrapper(*args, **kwargs)
#     132     elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     133         logger.warning(message)
# --> 134 return wrapped(*args, **kwargs)
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\googleapiclient\discovery.py:516, in build_from_document(service, base, future, http, developerKey, model, requestBuilder, credentials, client_options, adc_cert_path, adc_key_path)
#     513 # If the user didn't pass in credentials, attempt to acquire application
#     514 # default credentials.
#     515 if credentials is None:
# --> 516     credentials = _auth.default_credentials(
#     517         scopes=client_options.scopes,
#     518         quota_project_id=client_options.quota_project_id,
#     519     )
#     521 # The credentials need to be scoped.
#     522 # If the user provided scopes via client_options don't override them
#     523 if not client_options.scopes:
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\googleapiclient\_auth.py:54, in default_credentials(scopes, quota_project_id)
#      52 """Returns Application Default Credentials."""
#      53 if HAS_GOOGLE_AUTH:
# ---> 54     credentials, _ = google.auth.default(scopes=scopes, quota_project_id=quota_project_id)
#      55     return credentials
#      56 elif HAS_OAUTH2CLIENT:
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\google\auth\_default.py:691, in default(scopes, request, quota_project_id, default_scopes)
#     683             _LOGGER.warning(
#     684                 "No project ID could be determined. Consider running "
#     685                 "`gcloud config set project` or setting the %s "
#     686                 "environment variable",
#     687                 environment_vars.PROJECT,
#     688             )
#     689         return credentials, effective_project_id
# --> 691 raise exceptions.DefaultCredentialsError(_CLOUD_SDK_MISSING_CREDENTIALS)
#
# DefaultCredentialsError: Your default credentials were not found. To set up Application Default Credentials, see https://cloud.google.com/docs/authentication/external/set-up-adc for more information.

# %% [markdown]
# ## Output as Pandas DataFrame

# %%
import googleapiclient.discovery
import pandas as pd

api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = "AIzaSyDcPxN3CoGj4A29ZdF8M0iaOa_ksfBmqyI"

youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=DEVELOPER_KEY)

request = youtube.commentThreads().list(
    part="snippet",
    videoId="9dKdLNlmxco",
    maxResults=100
)
response = request.execute()

comments = []

for item in response['items']:
    comment = item['snippet']['topLevelComment']['snippet']
    comments.append([
        comment['authorDisplayName'],
        comment['publishedAt'],
        comment['updatedAt'],
        comment['likeCount'],
        comment['textDisplay']
    ])

df = pd.DataFrame(comments, columns=['author', 'published_at', 'updated_at', 'like_count', 'text'])

df.head(100)
# Out:
#                       author          published_at            updated_at  \
# 0                @Samtoosoon  2024-07-20T13:50:49Z  2024-07-20T13:50:49Z
# 1         @NAVEENKUMAR-uj7xe  2024-07-20T13:49:13Z  2024-07-20T13:49:13Z
# 2               @Rahul-pr1zr  2024-07-20T13:30:53Z  2024-07-20T13:30:53Z
# 3                @shreecolab  2024-07-20T13:18:20Z  2024-07-20T13:27:01Z
# 4                @chad._life  2024-07-20T12:07:47Z  2024-07-20T12:07:47Z
# 5         @pankajkashyap2892  2024-07-20T11:26:48Z  2024-07-20T11:26:48Z
# 6           @moneyonline5299  2024-07-20T10:45:28Z  2024-07-20T10:45:28Z
# 7    @divyanshkhandelwal5191  2024-07-20T09:52:22Z  2024-07-20T09:52:22Z
# 8          @k-CE-OmkarPathak  2024-07-20T08:57:01Z  2024-07-20T08:57:01Z
# 9                  @Rajdweep  2024-07-20T08:02:45Z  2024-07-20T08:02:45Z
# 10           @ayaanrashid960  2024-07-20T07:47:57Z  2024-07-20T07:47:57Z
# 11        @piyushchauhan2898  2024-07-20T07:36:20Z  2024-07-20T07:36:20Z
# 12                @abhinay.k  2024-07-20T05:54:18Z  2024-07-20T05:54:18Z
# 13  @dayashankarlakhotia4943  2024-07-20T05:41:27Z  2024-07-20T05:41:27Z
# 14        @srikanthsatya3226  2024-07-20T05:33:07Z  2024-07-20T05:33:07Z
